# %%
# Install Twint in current Juypter Kernal (may take a while, output will appear)
import sys
# !{sys.executable} -m pip install twint

# %%
# Import packages to use
import twint
import pandas as pd
import matplotlib.pyplot as plt

# Patches asyncio to allow the running of multiple event loops in Jupyter Notebooks.
# Fixes: "RuntimeError: This event loop is already running"
import nest_asyncio

nest_asyncio.apply()

# %%
# When used as a python module (as we are doing) TWINT can be configured with various function calls
# (search term, limit results, etc). Below we will configure a basic search for a specific users last 10 tweets.

# %%
# Get the last 10 tweets from a user and run
# Note the limit doesn't always work as expected (it may be counting tweets to limit but also displaying replies?)
c = twint.Config()

c.Username = 'jack'
c.Limit = 10

twint.run.Search(c)
# Out:
# 1265837143827468289 2020-05-28 03:47:47 GMT Daylight Time <jack> Per our Civic Integrity policy ( https://help.twitter.com/en/rules-and-policies/election-integrity-policy …), the tweets yesterday may mislead people into thinking they don’t need to register to get a ballot (only registered voters receive ballots). We’re updating the link on @realDonaldTrump’s tweet to make this more clear.
# 1265837139360485376 2020-05-28 03:47:46 GMT Daylight Time <jack> This does not make us an “arbiter of truth.” Our intention is to connect the dots of conflicting statements and show the information in dispute so people can judge for themselves. More transparency from us is critical so folks can clearly see the why behind our actions.
# ...

# %%
# TWINT has a large number of configuration options
# https://github.com/twintproject/twint/wiki/Configuration
# Some of the most useful are since, until and output

# %%
# Get a specific users tweets between dates shown and output to a csv file
# Check Jupyter homepage tab for csv file. Can be read into other python programs, Notebooks and cells.
c = twint.Config()

c.Username = 'jack'
c.Since = '2020-05-20 00:00:00'
c.Until = '2020-05-28 00:00:00'
c.Output_csv = True
c.Output = 'jack-tweets-20-28-may-2020.csv'

twint.run.Search(c)
# Out:
# 1265273270347026441 2020-05-26 14:27:09 GMT Daylight Time <jack> Incredible book by @stewartbrand. Best I’ve read this year.   “Cities are green. Nuclear energy is green. Genetic engineering is green.” https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewBook?id=394940796 …
# 1264249028029509634 2020-05-23 18:37:11 GMT Daylight Time <jack>  https://charleseisenstein.org/essays/the-conspiracy-myth/ …
# 1263921211236511744 2020-05-22 20:54:33 GMT Daylight Time <jack> 🍕
# 1263459839360897024 2020-05-21 14:21:14 GMT Daylight Time <jack> Here’s our podcast talking about it and a few other things: https://open.spotify.com/episode/1xb2GYUPxoGAprDj3G4Idz?si=pd25FJ0cT9OKaKTfnuP17Q …
# ...

# %%
# lets make the information easier to read and manipulate inside Jupyter by using Pandas dataframes (we imported pandas earlier)
# Display jacks tweets between 20th 28th May 2020

c = twint.Config()

c.Username = 'jack'
c.Since = '2020-05-20 00:00:00'
c.Until = '2020-05-28 00:00:00'
c.Pandas = True

twint.run.Search(c)
# Out:
# 1265273270347026441 2020-05-26 14:27:09 GMT Daylight Time <jack> Incredible book by @stewartbrand. Best I’ve read this year.   “Cities are green. Nuclear energy is green. Genetic engineering is green.” https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewBook?id=394940796 …
# 1264249028029509634 2020-05-23 18:37:11 GMT Daylight Time <jack>  https://charleseisenstein.org/essays/the-conspiracy-myth/ …
# 1263921211236511744 2020-05-22 20:54:33 GMT Daylight Time <jack> 🍕
# 1263459839360897024 2020-05-21 14:21:14 GMT Daylight Time <jack> Here’s our podcast talking about it and a few other things: https://open.spotify.com/episode/1xb2GYUPxoGAprDj3G4Idz?si=pd25FJ0cT9OKaKTfnuP17Q …
# ...

# %%
# Show the dataframe
df = twint.storage.panda.Tweets_df

df
# Out:
#                      id      conversation_id     created_at  \
# 0   1265273270347026441  1265273270347026441  1590499629000
# 1   1264249028029509634  1264249028029509634  1590255431000
# 2   1263921211236511744  1263921211236511744  1590177273000
# 3   1263459839360897024  1263459837708390400  1590067274000
# 4   1263459837708390400  1263459837708390400  1590067273000
# 5   1263316972009185280  1263316972009185280  1590033212000
# 6   1263302958860472320  1263302958860472320  1590029871000
# 7   1263214205756293120  1263214205756293120  1590008710000
# 8   1263183421263634432  1263181108180430849  1590001371000
# 9   1263181108180430849  1263181108180430849  1590000819000
# 10  1262921776838750209  1262921776838750209  1589938990000
# 11  1262920202972352512  1262920202972352512  1589938614000
#
#                    date           timezone place  \
# 0   2020-05-26 14:27:09  GMT Daylight Time
# 1   2020-05-23 18:37:11  GMT Daylight Time
# 2   2020-05-22 20:54:33  GMT Daylight Time
# ...

# %%
# Now thats easier to read. Use info() to show all the columns and their datatypes (useful for later manipulation)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               12 non-null     object
#  1   conversation_id  12 non-null     object
#  2   created_at       12 non-null     int64
#  3   date             12 non-null     object
#  4   timezone         12 non-null     object
#  5   place            12 non-null     object
#  6   tweet            12 non-null     object
#  7   hashtags         12 non-null     object
#  8   cashtags         12 non-null     object
#  9   user_id          12 non-null     int64
#  10  user_id_str      12 non-null     object
#  11  username         12 non-null     object
#  12  name             12 non-null     object
#  13  day              12 non-null     int64
#  14  hour             12 non-null     object
#  15  link             12 non-null     object
#  16  retweet          12 non-null     bool
# ...

# %%
# Display two columns of the dataframe, date and tweet
# Tweets will be truncated, however, this is useful for a preview.
# You can 'turn off' truncation by: pd.set_option('display.max_colwidth', None)
df[['date', 'tweet']]
# Out:
#                    date  \
# 0   2020-05-26 14:27:09
# 1   2020-05-23 18:37:11
# 2   2020-05-22 20:54:33
# 3   2020-05-21 14:21:14
# 4   2020-05-21 14:21:13
# 5   2020-05-21 04:53:32
# 6   2020-05-21 03:57:51
# 7   2020-05-20 22:05:10
# 8   2020-05-20 20:02:51
# 9   2020-05-20 19:53:39
# 10  2020-05-20 02:43:10
# 11  2020-05-20 02:36:54
#
#                                                                                                                                                                                                                                                                                 tweet
# 0                                                               Incredible book by @stewartbrand. Best I’ve read this year. \n\n“Cities are green. Nuclear energy is green. Genetic engineering is green.” https://itunes.apple.com/WebObjects/MZStore.woa/wa/viewBook?id=394940796 …
# ...

# %%
# That concludes the short introduction. I will upload a notebook which delves a little deeper
# including using matplotlib to graph data to gain insights

# If you end up using TWINT, do consider Patreon, even if you've never Patreon'd before
# nb. I have no affiliation with TWINT
